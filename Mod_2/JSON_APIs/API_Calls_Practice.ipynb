# %% [markdown]
# ## Starting Off
#
# Think of one lingering quetion you have about SQL and sedd it to our slack class channel.

# %% [markdown]
# # Using APIs and JSON Data

# %% [markdown]
# ## Objectives
# You will be able to:
# * Make an API call to Yelp

# %% [markdown]
# ## Agenda
#
# * Build up an API Call
# * Look at the results

# %%
import requests
import json

# %% [markdown]
# For more information about the request package you can use the following resources:
#
# **Tutorial:** https://realpython.com/python-requests/
#
# **Package Documentation:** https://requests.readthedocs.io/en/master/

# %% [markdown]
# ![](quota.png)

# %% [markdown]
# Let's do a serach of businesses on the Yelp API.

# %%
# set theurl and endpoint we want to hit
url = 'https://api.yelp.com/v3/businesses/search'

# %% [markdown]
# Now that you have an API key, let's enter set that information here so that we can do our searches. Once you have the `api_key` variable, place int in our header.

# %%
client_id = "F475wXQIdgD3Q7epch9QDA"
api_key = "k6TYJi5qpisv2T3ZgvU2QpxXoJ6b5zEMbS7wJFKyvFlDMASkuvLUMKcMGfU4K5iefWZRT0TSMuAe77IIJxmg8hFW6aq_4NtijcWYp6w3i1yRfNOIZFdu5241j2LpXXYx"

# %%
#client_id = 'bVX1Jsfp4dkIOqw5HOVplg' #Your client ID goes here (as a string)
#api_key = 'RTzp-q-TgkJW_NFQogubFvZNRDziXyoR38VbtZMWibDI-FlvB25OE7GmafFEqhTL8_Bk2HlcX24-hRWLMP7Nc6WHO_VXMXldpPBjP0LoPv5EFFELMSI2oll8njhbXHYx' #Your api key goes here (as a string)

# %%
headers = {
        'Authorization': 'Bearer {}'.format(api_key),
    }

# %% [markdown]
# We now need to determine our parameters we want to pass.
#
# You must give a specific search term, location and one other paramter to limit your search.
#
# Remember you can search the API documenation to find another parameter to limit your search.
# https://www.yelp.com/developers/documentation/v3/get_started

# %%
# what type of business do you want to search
term = 'Garden'

#where do you want to perform this search
location = 'Alphabet City'

# what is your other parameter you want to search against
radius = 1000

# %%
url_params = {
                'term': term.replace(' ', '+'),
                'location': location.replace(' ', '+'),
                'radius' : radius
            }

# %% [markdown]
# Now that we have all of the parts necessary for an API call, let's put them together.

# %%
response = requests.get(url, headers=headers, params=url_params)

# %% [markdown]
# ## The Response
#
# The response of a GET request often has some valuable information, known as a payload, in the message body. Using the attributes and methods of Response, you can view the payload in a variety of different formats.
#
# To see the response’s content in bytes, you use `.content`
#
# You will often want to convert them into a string using a character encoding such as UTF-8. Response will do that for you when you access `.text`
#
# The response is actually serialized JSON content. To get a dictionary, you could take the str you retrieved from `.text` and deserialize it using `json.loads()`. However, a simpler way to accomplish this task is to use `.json()`:

# %%
json.loads(response.text)
# Out:
# {'businesses': [{'id': 'DIlYrrrns-blsOd3uqjUgg',
#    'alias': 'creative-little-garden-new-york',
#    'name': 'Creative Little Garden',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/X1NWjwfNgJJADwQ50ozZ3g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/creative-little-garden-new-york?adjust_creative=F475wXQIdgD3Q7epch9QDA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=F475wXQIdgD3Q7epch9QDA',
#    'review_count': 30,
#    'categories': [{'alias': 'gardens', 'title': 'Botanical Gardens'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7246453, 'longitude': -73.9823734},
#    'transactions': [],
#    'location': {'address1': '530 E 6th St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10009',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['530 E 6th St', 'New York, NY 10009']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 221.7864603513625},
#   {'id': 'nuvIEeqYLrivKMdgKLXPlA',
#    'alias': '6bc-botanical-garden-new-york-2',
#    'name': '6BC Botanical Garden',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/WH_Rjl245hmsxwXGmmA4RA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/6bc-botanical-garden-new-york-2?adjust_creative=F475wXQIdgD3Q7epch9QDA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=F475wXQIdgD3Q7epch9QDA',
#    'review_count': 25,
#    'categories': [{'alias': 'parks', 'title': 'Parks'},
#     {'alias': 'gardens', 'title': 'Botanical Gardens'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 40.724105, 'longitude': -73.980687},
#    'transactions': [],
#    'location': {'address1': '624 6th St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10009',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['624 6th St', 'New York, NY 10009']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 106.11068811197765},
#   {'id': 'FT9nDuJRsz4CnuREC8tDYA',
#    'alias': 'saifee-hardware-and-garden-new-york',
#    'name': 'Saifee Hardware & Garden',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/HKRCc0V0lKIjG2IBD_h9Gw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/saifee-hardware-and-garden-new-york?adjust_creative=F475wXQIdgD3Q7epch9QDA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=F475wXQIdgD3Q7epch9QDA',
#    'review_count': 52,
#    'categories': [{'alias': 'gardening', 'title': 'Nurseries & Gardening'},
#     {'alias': 'hardware', 'title': 'Hardware Stores'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7267951, 'longitude': -73.9855885},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '114 1st Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10009',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['114 1st Ave', 'New York, NY 10009']},
#    'phone': '+12129796396',
#    'display_phone': '(212) 979-6396',
#    'distance': 519.7756861712467},
#   {'id': 'kOFMiniI6AF2Ohw0Q-QUhw',
#    'alias': '9th-street-community-garden-park-new-york',
#    'name': '9th Street Community Garden Park',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/3gzvF4cY94frxr_7DihQuQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/9th-street-community-garden-park-new-york?adjust_creative=F475wXQIdgD3Q7epch9QDA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=F475wXQIdgD3Q7epch9QDA',
#    'review_count': 4,
#    'categories': [{'alias': 'communitygardens', 'title': 'Community Gardens'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7251, 'longitude': -73.9778},
#    'transactions': [],
#    'location': {'address1': '700 E 9th St Ave C',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10009',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['700 E 9th St Ave C', 'New York, NY 10009']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 181.19909101671928},
#   {'id': '-jTr7AKW7ZVD0MOI-evCEA',
#    'alias': 'miracle-garden-new-york',
#    'name': 'Miracle Garden',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/8bHu-MiUf-poHVFxDgsBwA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/miracle-garden-new-york?adjust_creative=F475wXQIdgD3Q7epch9QDA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=F475wXQIdgD3Q7epch9QDA',
#    'review_count': 2,
#    'categories': [{'alias': 'parks', 'title': 'Parks'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7226354149576,
#     'longitude': -73.9835025380507},
#    'transactions': [],
#    'location': {'address1': '196 E 3rd St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10009',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['196 E 3rd St', 'New York, NY 10009']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 389.43016803656326},
#   {'id': 'jvPYm9rYK-5ddnjU30Oz4Q',
#    'alias': 'avant-garden-new-york',
#    'name': 'Avant Garden',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/O75v7I193A26GbaW5ggfYg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/avant-garden-new-york?adjust_creative=F475wXQIdgD3Q7epch9QDA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=F475wXQIdgD3Q7epch9QDA',
#    'review_count': 313,
#    'categories': [{'alias': 'newamerican', 'title': 'American (New)'},
#     {'alias': 'vegan', 'title': 'Vegan'},
#     {'alias': 'vegetarian', 'title': 'Vegetarian'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7261499, 'longitude': -73.98402},
#    'transactions': [],
#    'price': '$$$',
#    'location': {'address1': '130 E 7th St',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10009',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['130 E 7th St', 'New York, NY 10009']},
#    'phone': '+16469227948',
#    'display_phone': '(646) 922-7948',
#    'distance': 363.9279528380816},
#   {'id': '5ToSohJi-0RkfEf1Bsw5Kw',
#    'alias': 'blue-meadow-flowers-new-york',
#    'name': 'Blue Meadow Flowers',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/RPmK89R1xQWu9Z5CR2uyvQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/blue-meadow-flowers-new-york?adjust_creative=F475wXQIdgD3Q7epch9QDA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=F475wXQIdgD3Q7epch9QDA',
#    'review_count': 10,
#    'categories': [{'alias': 'florists', 'title': 'Florists'},
#     {'alias': 'gardening', 'title': 'Nurseries & Gardening'},
#     {'alias': 'eventplanning', 'title': 'Party & Event Planning'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 40.7310556, 'longitude': -73.9843779},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '336 E 13th St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10003',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['336 E 13th St', 'New York, NY 10003']},
#    'phone': '+12129798618',
#    'display_phone': '(212) 979-8618',
#    'distance': 768.5246821175758},
#   {'id': 'h-SW6kadPdU5JGqY9eTCCg',
#    'alias': 'crystals-garden-new-york-3',
#    'name': 'Crystals Garden',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/BLizaAvz6WQq4iVVrFATZQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/crystals-garden-new-york-3?adjust_creative=F475wXQIdgD3Q7epch9QDA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=F475wXQIdgD3Q7epch9QDA',
#    'review_count': 55,
#    'categories': [{'alias': 'flowers', 'title': 'Flowers & Gifts'},
#     {'alias': 'jewelry', 'title': 'Jewelry'},
#     {'alias': 'spiritual_shop', 'title': 'Spiritual Shop'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.728947, 'longitude': -73.983941},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '247 E 10th St',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10009',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['247 E 10th St', 'New York, NY 10009']},
#    'phone': '+12124755710',
#    'display_phone': '(212) 475-5710',
#    'distance': 562.7492053827375},
#   {'id': '8Ku8yOA5LeMruzn8jkyAKQ',
#    'alias': 'green-oasis-garden-new-york',
#    'name': 'Green Oasis Garden',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/CbZTZLqKXpB8ArWEUKRQNQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/green-oasis-garden-new-york?adjust_creative=F475wXQIdgD3Q7epch9QDA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=F475wXQIdgD3Q7epch9QDA',
#    'review_count': 2,
#    'categories': [{'alias': 'communitygardens', 'title': 'Community Gardens'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 40.723978, 'longitude': -73.977343},
#    'transactions': [],
#    'location': {'address1': '8th St Ave C & D',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10079',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['8th St Ave C & D', 'New York, NY 10079']},
#    'phone': '+12122131588',
#    'display_phone': '(212) 213-1588',
#    'distance': 242.40985325280192},
#   {'id': 'G6wD8ykZYqtr_rfllNAkvw',
#    'alias': 'dias-y-flores-garden-new-york-2',
#    'name': 'Dias Y Flores Garden',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/ZlU1nTUnzignE66xWLlVSQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/dias-y-flores-garden-new-york-2?adjust_creative=F475wXQIdgD3Q7epch9QDA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=F475wXQIdgD3Q7epch9QDA',
#    'review_count': 1,
#    'categories': [{'alias': 'communitygardens', 'title': 'Community Gardens'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 40.729106, 'longitude': -73.979972},
#    'transactions': [],
#    'location': {'address1': '520-522 E 13th St',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10009',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['520-522 E 13th St', 'New York, NY 10009']},
#    'phone': '+18305342615',
#    'display_phone': '(830) 534-2615',
#    'distance': 472.08042754623915},
#   {'id': 'wLXdOW03GRgtw4tZnDZBKA',
#    'alias': '11th-street-community-garden-new-york',
#    'name': '11th Street Community Garden',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/2N-7st2IJz3MpaJRYB46sg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/11th-street-community-garden-new-york?adjust_creative=F475wXQIdgD3Q7epch9QDA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=F475wXQIdgD3Q7epch9QDA',
#    'review_count': 2,
#    'categories': [{'alias': 'communitygardens', 'title': 'Community Gardens'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.7285423278809,
#     'longitude': -73.9828948974609},
#    'transactions': [],
#    'location': {'address1': '422 E 11th St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10009',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['422 E 11th St', 'New York, NY 10009']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 476.10080718331295},
#   {'id': 'z_Ne8n6ckJH8QAx11Q3X4w',
#    'alias': '6th-and-b-garden-new-york',
#    'name': '6th & B Garden',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/Hgi5qTAtemSqoCPWFvMnZQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/6th-and-b-garden-new-york?adjust_creative=F475wXQIdgD3Q7epch9QDA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=F475wXQIdgD3Q7epch9QDA',
#    'review_count': 11,
#    'categories': [{'alias': 'parks', 'title': 'Parks'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7244911353936,
#     'longitude': -73.9816318338447},
#    'transactions': [],
#    'location': {'address1': 'Corner Of 6th St And Ave B',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10009',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['Corner Of 6th St And Ave B', 'New York, NY 10009']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 147.49448663722438},
#   {'id': 'R_78uC7FRmlCAdESzQfpBg',
#    'alias': 'el-sol-brillante-sr-new-york',
#    'name': 'El Sol Brillante Sr',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/m5PU33sbn64TVVJM0hrk7A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/el-sol-brillante-sr-new-york?adjust_creative=F475wXQIdgD3Q7epch9QDA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=F475wXQIdgD3Q7epch9QDA',
#    'review_count': 2,
#    'categories': [{'alias': 'parks', 'title': 'Parks'},
#     {'alias': 'communitygardens', 'title': 'Community Gardens'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 40.728658, 'longitude': -73.979505},
#    'transactions': [],
#    'location': {'address1': '537 East 12th St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10009',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['537 East 12th St', 'New York, NY 10009']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 421.4060503392973},
#   {'id': '4L_Dn2NtGPXisnjHQ5WKVg',
#    'alias': 'carmen-pabon-del-amanecer-garden-new-york',
#    'name': 'Carmen Pabon del Amanecer Garden',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/zXdeH8y1W-jex_cMBsLP7Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/carmen-pabon-del-amanecer-garden-new-york?adjust_creative=F475wXQIdgD3Q7epch9QDA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=F475wXQIdgD3Q7epch9QDA',
#    'review_count': 1,
#    'categories': [{'alias': 'communitygardens', 'title': 'Community Gardens'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 40.7246759864857,
#     'longitude': -73.9787411108399},
#    'transactions': [],
#    'location': {'address1': '115 Avenue C',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10009',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['115 Avenue C', 'New York, NY 10009']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 105.24199196522034},
#   {'id': 'SYS6Azea3ZZw1F0FQcW_Mg',
#    'alias': 'el-jardin-del-paraiso-new-york',
#    'name': 'El Jardin del Paraiso',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/vGT_S9x2Z3_MdH-tjfRdbg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/el-jardin-del-paraiso-new-york?adjust_creative=F475wXQIdgD3Q7epch9QDA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=F475wXQIdgD3Q7epch9QDA',
#    'review_count': 3,
#    'categories': [{'alias': 'gardens', 'title': 'Botanical Gardens'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.7223636825473,
#     'longitude': -73.9792042049713},
#    'transactions': [],
#    'location': {'address1': 'E 4th & 5th St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10019',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['E 4th & 5th St', 'New York, NY 10019']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 287.3704471158173},
#   {'id': '6Zeurt0hPz4Voj_I5Uq6Mg',
#    'alias': 'rue-b-new-york',
#    'name': 'Rue B',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/ePNEOCc-y5g4SWIHWZ8HGA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/rue-b-new-york?adjust_creative=F475wXQIdgD3Q7epch9QDA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=F475wXQIdgD3Q7epch9QDA',
#    'review_count': 305,
#    'categories': [{'alias': 'bars', 'title': 'Bars'},
#     {'alias': 'jazzandblues', 'title': 'Jazz & Blues'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.727958, 'longitude': -73.979415},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '188 Ave B',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10009',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['188 Ave B', 'New York, NY 10009']},
#    'phone': '+12123581700',
#    'display_phone': '(212) 358-1700',
#    'distance': 342.94327162949264},
#   {'id': 'f3gTNiaMBpPQTP-cSjfWhA',
#    'alias': 'sages-garden-new-york',
#    'name': "Sage's Garden",
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/gOwpHjFYj9NeNmAVsQsMLA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/sages-garden-new-york?adjust_creative=F475wXQIdgD3Q7epch9QDA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=F475wXQIdgD3Q7epch9QDA',
#    'review_count': 1,
#    'categories': [{'alias': 'communitygardens', 'title': 'Community Gardens'},
#     {'alias': 'parks', 'title': 'Parks'}],
#    'rating': 3.0,
#    'coordinates': {'latitude': 40.7227477441493,
#     'longitude': -73.9810416559094},
#    'transactions': [],
#    'location': {'address1': '281 E 4th St',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10009',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['281 E 4th St', 'New York, NY 10009']},
#    'phone': '+12126025300',
#    'display_phone': '(212) 602-5300',
#    'distance': 254.43240909236613},
#   {'id': '7mGYvIC9Ap1-CUxHFG53Xg',
#    'alias': 'hope-garden-new-york',
#    'name': 'Hope Garden',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/S3ozRMyGadl0rzLvSqlWyA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/hope-garden-new-york?adjust_creative=F475wXQIdgD3Q7epch9QDA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=F475wXQIdgD3Q7epch9QDA',
#    'review_count': 1,
#    'categories': [{'alias': 'communitygardens', 'title': 'Community Gardens'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.722228080638,
#     'longitude': -73.9841856908627},
#    'transactions': [],
#    'location': {'address1': '191 E 2nd St',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10009',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['191 E 2nd St', 'New York, NY 10009']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 462.6536858063071},
#   {'id': '1MS5BSbYYpqj0cONFxZaUw',
#    'alias': 'orchard-alley-new-york',
#    'name': 'Orchard Alley',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/aZHw2Pu371Ojop_udiTk2Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/orchard-alley-new-york?adjust_creative=F475wXQIdgD3Q7epch9QDA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=F475wXQIdgD3Q7epch9QDA',
#    'review_count': 1,
#    'categories': [{'alias': 'communitygardens', 'title': 'Community Gardens'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7213268365183,
#     'longitude': -73.9785251420265},
#    'transactions': [],
#    'location': {'address1': '350 E 4th St',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10009',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['350 E 4th St', 'New York, NY 10009']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 413.5827970434387},
#   {'id': 'dh5r9-SbN8xJ76XvnayWLQ',
#    'alias': 'giano-restaurant-new-york',
#    'name': 'Giano Restaurant',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/0PrOZ5stl86k6V1SzHcjNA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/giano-restaurant-new-york?adjust_creative=F475wXQIdgD3Q7epch9QDA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=F475wXQIdgD3Q7epch9QDA',
#    'review_count': 569,
#    'categories': [{'alias': 'italian', 'title': 'Italian'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7262256596862,
#     'longitude': -73.9840574049125},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '126 E 7th St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10009',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['126 E 7th St', 'New York, NY 10009']},
#    'phone': '+12126737200',
#    'display_phone': '(212) 673-7200',
#    'distance': 376.1769110620603}],
#  'total': 251,
#  'region': {'center': {'longitude': -73.97995948791504,
#    'latitude': 40.724883883567564}}}

# %%
response.json()
# Out:
# {'businesses': [{'id': 'DIlYrrrns-blsOd3uqjUgg',
#    'alias': 'creative-little-garden-new-york',
#    'name': 'Creative Little Garden',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/X1NWjwfNgJJADwQ50ozZ3g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/creative-little-garden-new-york?adjust_creative=F475wXQIdgD3Q7epch9QDA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=F475wXQIdgD3Q7epch9QDA',
#    'review_count': 30,
#    'categories': [{'alias': 'gardens', 'title': 'Botanical Gardens'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7246453, 'longitude': -73.9823734},
#    'transactions': [],
#    'location': {'address1': '530 E 6th St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10009',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['530 E 6th St', 'New York, NY 10009']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 221.7864603513625},
#   {'id': 'nuvIEeqYLrivKMdgKLXPlA',
#    'alias': '6bc-botanical-garden-new-york-2',
#    'name': '6BC Botanical Garden',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/WH_Rjl245hmsxwXGmmA4RA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/6bc-botanical-garden-new-york-2?adjust_creative=F475wXQIdgD3Q7epch9QDA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=F475wXQIdgD3Q7epch9QDA',
#    'review_count': 25,
#    'categories': [{'alias': 'parks', 'title': 'Parks'},
#     {'alias': 'gardens', 'title': 'Botanical Gardens'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 40.724105, 'longitude': -73.980687},
#    'transactions': [],
#    'location': {'address1': '624 6th St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10009',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['624 6th St', 'New York, NY 10009']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 106.11068811197765},
#   {'id': 'FT9nDuJRsz4CnuREC8tDYA',
#    'alias': 'saifee-hardware-and-garden-new-york',
#    'name': 'Saifee Hardware & Garden',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/HKRCc0V0lKIjG2IBD_h9Gw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/saifee-hardware-and-garden-new-york?adjust_creative=F475wXQIdgD3Q7epch9QDA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=F475wXQIdgD3Q7epch9QDA',
#    'review_count': 52,
#    'categories': [{'alias': 'gardening', 'title': 'Nurseries & Gardening'},
#     {'alias': 'hardware', 'title': 'Hardware Stores'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7267951, 'longitude': -73.9855885},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '114 1st Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10009',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['114 1st Ave', 'New York, NY 10009']},
#    'phone': '+12129796396',
#    'display_phone': '(212) 979-6396',
#    'distance': 519.7756861712467},
#   {'id': 'kOFMiniI6AF2Ohw0Q-QUhw',
#    'alias': '9th-street-community-garden-park-new-york',
#    'name': '9th Street Community Garden Park',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/3gzvF4cY94frxr_7DihQuQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/9th-street-community-garden-park-new-york?adjust_creative=F475wXQIdgD3Q7epch9QDA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=F475wXQIdgD3Q7epch9QDA',
#    'review_count': 4,
#    'categories': [{'alias': 'communitygardens', 'title': 'Community Gardens'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7251, 'longitude': -73.9778},
#    'transactions': [],
#    'location': {'address1': '700 E 9th St Ave C',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10009',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['700 E 9th St Ave C', 'New York, NY 10009']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 181.19909101671928},
#   {'id': '-jTr7AKW7ZVD0MOI-evCEA',
#    'alias': 'miracle-garden-new-york',
#    'name': 'Miracle Garden',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/8bHu-MiUf-poHVFxDgsBwA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/miracle-garden-new-york?adjust_creative=F475wXQIdgD3Q7epch9QDA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=F475wXQIdgD3Q7epch9QDA',
#    'review_count': 2,
#    'categories': [{'alias': 'parks', 'title': 'Parks'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7226354149576,
#     'longitude': -73.9835025380507},
#    'transactions': [],
#    'location': {'address1': '196 E 3rd St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10009',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['196 E 3rd St', 'New York, NY 10009']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 389.43016803656326},
#   {'id': 'jvPYm9rYK-5ddnjU30Oz4Q',
#    'alias': 'avant-garden-new-york',
#    'name': 'Avant Garden',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/O75v7I193A26GbaW5ggfYg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/avant-garden-new-york?adjust_creative=F475wXQIdgD3Q7epch9QDA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=F475wXQIdgD3Q7epch9QDA',
#    'review_count': 313,
#    'categories': [{'alias': 'newamerican', 'title': 'American (New)'},
#     {'alias': 'vegan', 'title': 'Vegan'},
#     {'alias': 'vegetarian', 'title': 'Vegetarian'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7261499, 'longitude': -73.98402},
#    'transactions': [],
#    'price': '$$$',
#    'location': {'address1': '130 E 7th St',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10009',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['130 E 7th St', 'New York, NY 10009']},
#    'phone': '+16469227948',
#    'display_phone': '(646) 922-7948',
#    'distance': 363.9279528380816},
#   {'id': '5ToSohJi-0RkfEf1Bsw5Kw',
#    'alias': 'blue-meadow-flowers-new-york',
#    'name': 'Blue Meadow Flowers',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/RPmK89R1xQWu9Z5CR2uyvQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/blue-meadow-flowers-new-york?adjust_creative=F475wXQIdgD3Q7epch9QDA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=F475wXQIdgD3Q7epch9QDA',
#    'review_count': 10,
#    'categories': [{'alias': 'florists', 'title': 'Florists'},
#     {'alias': 'gardening', 'title': 'Nurseries & Gardening'},
#     {'alias': 'eventplanning', 'title': 'Party & Event Planning'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 40.7310556, 'longitude': -73.9843779},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '336 E 13th St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10003',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['336 E 13th St', 'New York, NY 10003']},
#    'phone': '+12129798618',
#    'display_phone': '(212) 979-8618',
#    'distance': 768.5246821175758},
#   {'id': 'h-SW6kadPdU5JGqY9eTCCg',
#    'alias': 'crystals-garden-new-york-3',
#    'name': 'Crystals Garden',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/BLizaAvz6WQq4iVVrFATZQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/crystals-garden-new-york-3?adjust_creative=F475wXQIdgD3Q7epch9QDA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=F475wXQIdgD3Q7epch9QDA',
#    'review_count': 55,
#    'categories': [{'alias': 'flowers', 'title': 'Flowers & Gifts'},
#     {'alias': 'jewelry', 'title': 'Jewelry'},
#     {'alias': 'spiritual_shop', 'title': 'Spiritual Shop'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.728947, 'longitude': -73.983941},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '247 E 10th St',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10009',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['247 E 10th St', 'New York, NY 10009']},
#    'phone': '+12124755710',
#    'display_phone': '(212) 475-5710',
#    'distance': 562.7492053827375},
#   {'id': '8Ku8yOA5LeMruzn8jkyAKQ',
#    'alias': 'green-oasis-garden-new-york',
#    'name': 'Green Oasis Garden',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/CbZTZLqKXpB8ArWEUKRQNQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/green-oasis-garden-new-york?adjust_creative=F475wXQIdgD3Q7epch9QDA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=F475wXQIdgD3Q7epch9QDA',
#    'review_count': 2,
#    'categories': [{'alias': 'communitygardens', 'title': 'Community Gardens'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 40.723978, 'longitude': -73.977343},
#    'transactions': [],
#    'location': {'address1': '8th St Ave C & D',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10079',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['8th St Ave C & D', 'New York, NY 10079']},
#    'phone': '+12122131588',
#    'display_phone': '(212) 213-1588',
#    'distance': 242.40985325280192},
#   {'id': 'G6wD8ykZYqtr_rfllNAkvw',
#    'alias': 'dias-y-flores-garden-new-york-2',
#    'name': 'Dias Y Flores Garden',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/ZlU1nTUnzignE66xWLlVSQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/dias-y-flores-garden-new-york-2?adjust_creative=F475wXQIdgD3Q7epch9QDA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=F475wXQIdgD3Q7epch9QDA',
#    'review_count': 1,
#    'categories': [{'alias': 'communitygardens', 'title': 'Community Gardens'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 40.729106, 'longitude': -73.979972},
#    'transactions': [],
#    'location': {'address1': '520-522 E 13th St',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10009',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['520-522 E 13th St', 'New York, NY 10009']},
#    'phone': '+18305342615',
#    'display_phone': '(830) 534-2615',
#    'distance': 472.08042754623915},
#   {'id': 'wLXdOW03GRgtw4tZnDZBKA',
#    'alias': '11th-street-community-garden-new-york',
#    'name': '11th Street Community Garden',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/2N-7st2IJz3MpaJRYB46sg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/11th-street-community-garden-new-york?adjust_creative=F475wXQIdgD3Q7epch9QDA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=F475wXQIdgD3Q7epch9QDA',
#    'review_count': 2,
#    'categories': [{'alias': 'communitygardens', 'title': 'Community Gardens'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.7285423278809,
#     'longitude': -73.9828948974609},
#    'transactions': [],
#    'location': {'address1': '422 E 11th St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10009',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['422 E 11th St', 'New York, NY 10009']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 476.10080718331295},
#   {'id': 'z_Ne8n6ckJH8QAx11Q3X4w',
#    'alias': '6th-and-b-garden-new-york',
#    'name': '6th & B Garden',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/Hgi5qTAtemSqoCPWFvMnZQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/6th-and-b-garden-new-york?adjust_creative=F475wXQIdgD3Q7epch9QDA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=F475wXQIdgD3Q7epch9QDA',
#    'review_count': 11,
#    'categories': [{'alias': 'parks', 'title': 'Parks'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7244911353936,
#     'longitude': -73.9816318338447},
#    'transactions': [],
#    'location': {'address1': 'Corner Of 6th St And Ave B',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10009',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['Corner Of 6th St And Ave B', 'New York, NY 10009']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 147.49448663722438},
#   {'id': 'R_78uC7FRmlCAdESzQfpBg',
#    'alias': 'el-sol-brillante-sr-new-york',
#    'name': 'El Sol Brillante Sr',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/m5PU33sbn64TVVJM0hrk7A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/el-sol-brillante-sr-new-york?adjust_creative=F475wXQIdgD3Q7epch9QDA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=F475wXQIdgD3Q7epch9QDA',
#    'review_count': 2,
#    'categories': [{'alias': 'parks', 'title': 'Parks'},
#     {'alias': 'communitygardens', 'title': 'Community Gardens'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 40.728658, 'longitude': -73.979505},
#    'transactions': [],
#    'location': {'address1': '537 East 12th St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10009',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['537 East 12th St', 'New York, NY 10009']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 421.4060503392973},
#   {'id': '4L_Dn2NtGPXisnjHQ5WKVg',
#    'alias': 'carmen-pabon-del-amanecer-garden-new-york',
#    'name': 'Carmen Pabon del Amanecer Garden',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/zXdeH8y1W-jex_cMBsLP7Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/carmen-pabon-del-amanecer-garden-new-york?adjust_creative=F475wXQIdgD3Q7epch9QDA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=F475wXQIdgD3Q7epch9QDA',
#    'review_count': 1,
#    'categories': [{'alias': 'communitygardens', 'title': 'Community Gardens'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 40.7246759864857,
#     'longitude': -73.9787411108399},
#    'transactions': [],
#    'location': {'address1': '115 Avenue C',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10009',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['115 Avenue C', 'New York, NY 10009']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 105.24199196522034},
#   {'id': 'SYS6Azea3ZZw1F0FQcW_Mg',
#    'alias': 'el-jardin-del-paraiso-new-york',
#    'name': 'El Jardin del Paraiso',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/vGT_S9x2Z3_MdH-tjfRdbg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/el-jardin-del-paraiso-new-york?adjust_creative=F475wXQIdgD3Q7epch9QDA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=F475wXQIdgD3Q7epch9QDA',
#    'review_count': 3,
#    'categories': [{'alias': 'gardens', 'title': 'Botanical Gardens'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.7223636825473,
#     'longitude': -73.9792042049713},
#    'transactions': [],
#    'location': {'address1': 'E 4th & 5th St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10019',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['E 4th & 5th St', 'New York, NY 10019']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 287.3704471158173},
#   {'id': '6Zeurt0hPz4Voj_I5Uq6Mg',
#    'alias': 'rue-b-new-york',
#    'name': 'Rue B',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/ePNEOCc-y5g4SWIHWZ8HGA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/rue-b-new-york?adjust_creative=F475wXQIdgD3Q7epch9QDA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=F475wXQIdgD3Q7epch9QDA',
#    'review_count': 305,
#    'categories': [{'alias': 'bars', 'title': 'Bars'},
#     {'alias': 'jazzandblues', 'title': 'Jazz & Blues'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.727958, 'longitude': -73.979415},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '188 Ave B',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10009',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['188 Ave B', 'New York, NY 10009']},
#    'phone': '+12123581700',
#    'display_phone': '(212) 358-1700',
#    'distance': 342.94327162949264},
#   {'id': 'f3gTNiaMBpPQTP-cSjfWhA',
#    'alias': 'sages-garden-new-york',
#    'name': "Sage's Garden",
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/gOwpHjFYj9NeNmAVsQsMLA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/sages-garden-new-york?adjust_creative=F475wXQIdgD3Q7epch9QDA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=F475wXQIdgD3Q7epch9QDA',
#    'review_count': 1,
#    'categories': [{'alias': 'communitygardens', 'title': 'Community Gardens'},
#     {'alias': 'parks', 'title': 'Parks'}],
#    'rating': 3.0,
#    'coordinates': {'latitude': 40.7227477441493,
#     'longitude': -73.9810416559094},
#    'transactions': [],
#    'location': {'address1': '281 E 4th St',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10009',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['281 E 4th St', 'New York, NY 10009']},
#    'phone': '+12126025300',
#    'display_phone': '(212) 602-5300',
#    'distance': 254.43240909236613},
#   {'id': '7mGYvIC9Ap1-CUxHFG53Xg',
#    'alias': 'hope-garden-new-york',
#    'name': 'Hope Garden',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/S3ozRMyGadl0rzLvSqlWyA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/hope-garden-new-york?adjust_creative=F475wXQIdgD3Q7epch9QDA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=F475wXQIdgD3Q7epch9QDA',
#    'review_count': 1,
#    'categories': [{'alias': 'communitygardens', 'title': 'Community Gardens'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.722228080638,
#     'longitude': -73.9841856908627},
#    'transactions': [],
#    'location': {'address1': '191 E 2nd St',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10009',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['191 E 2nd St', 'New York, NY 10009']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 462.6536858063071},
#   {'id': '1MS5BSbYYpqj0cONFxZaUw',
#    'alias': 'orchard-alley-new-york',
#    'name': 'Orchard Alley',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/aZHw2Pu371Ojop_udiTk2Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/orchard-alley-new-york?adjust_creative=F475wXQIdgD3Q7epch9QDA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=F475wXQIdgD3Q7epch9QDA',
#    'review_count': 1,
#    'categories': [{'alias': 'communitygardens', 'title': 'Community Gardens'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7213268365183,
#     'longitude': -73.9785251420265},
#    'transactions': [],
#    'location': {'address1': '350 E 4th St',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10009',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['350 E 4th St', 'New York, NY 10009']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 413.5827970434387},
#   {'id': 'dh5r9-SbN8xJ76XvnayWLQ',
#    'alias': 'giano-restaurant-new-york',
#    'name': 'Giano Restaurant',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/0PrOZ5stl86k6V1SzHcjNA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/giano-restaurant-new-york?adjust_creative=F475wXQIdgD3Q7epch9QDA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=F475wXQIdgD3Q7epch9QDA',
#    'review_count': 569,
#    'categories': [{'alias': 'italian', 'title': 'Italian'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7262256596862,
#     'longitude': -73.9840574049125},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '126 E 7th St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10009',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['126 E 7th St', 'New York, NY 10009']},
#    'phone': '+12126737200',
#    'display_phone': '(212) 673-7200',
#    'distance': 376.1769110620603}],
#  'total': 251,
#  'region': {'center': {'longitude': -73.97995948791504,
#    'latitude': 40.724883883567564}}}

# %% [markdown]
# Now let's go a bit further and start to preview what's stored in each of the values for these keys.

# %%
data = response.json()

# %%
for key in data.keys():
    print(key)
    value = response.json()[key] #Use standard dictionary formatting
    print(type(value)) #What type is it?
    print('\n\n') #Seperate out data
# Out:
# businesses
# <class 'list'>
#
#
#
# total
# <class 'int'>
#
#
#
# region
# <class 'dict'>

# %% [markdown]
# Let's make sure our data is as expected by looking at a couple of different business by taking a slice of the data.

# %%
data['businesses'][0:3]
# Out:
# [{'id': 'igcUHNvsKc-s-RtvUmkg2w',
#   'alias': 'kook-new-york',
#   'name': "K'OOK",
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/CFFjwXRiLmE4lgDiQ8lLbA/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/kook-new-york?adjust_creative=F475wXQIdgD3Q7epch9QDA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=F475wXQIdgD3Q7epch9QDA',
#   'review_count': 417,
#   'categories': [{'alias': 'korean', 'title': 'Korean'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 40.72682, 'longitude': -73.98738},
#   'transactions': ['pickup', 'delivery'],
#   'price': '$$',
#   'location': {'address1': '324 E 6th St',
#    'address2': None,
#    'address3': '',
#    'city': 'New York',
#    'zip_code': '10003',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['324 E 6th St', 'New York, NY 10003']},
#   'phone': '+12122540600',
#   'display_phone': '(212) 254-0600',
#   'distance': 441.04087011252744},
#  {'id': 'LMyvruexOQzzHQrAgbdqiA',
#   'alias': 'nowon-new-york-2',
#   'name': 'Nowon',
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/7zLJSYykomkFaOegcx5kbA/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/nowon-new-york-2?adjust_creative=F475wXQIdgD3Q7epch9QDA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=F475wXQIdgD3Q7epch9QDA',
#   'review_count': 7,
#   'categories': [{'alias': 'korean', 'title': 'Korean'},
#    {'alias': 'newamerican', 'title': 'American (New)'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 40.72532, 'longitude': -73.98334},
#   'transactions': [],
#   'location': {'address1': '507 East 6th St',
#    'address2': None,
#    'address3': '',
#    'city': 'New York',
#    'zip_code': '10009',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['507 East 6th St', 'New York, NY 10009']},
#   'phone': '+16466923867',
#   'display_phone': '(646) 692-3867',
#   'distance': 164.5820748251596},
#  {'id': 'fVbUVAiLiGgLA_nxBFxyww',
#   'alias': 'thursday-kitchen-new-york',
#   'name': 'Thursday Kitchen',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/5P_HFhM6w8cRK3IiCzrNTQ/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/thursday-kitchen-new-york?adjust_creative=F475wXQIdgD3Q7epch9QDA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=F475wXQIdgD3Q7epch9QDA',
#   'review_count': 1275,
#   'categories': [{'alias': 'korean', 'title': 'Korean'},
#    {'alias': 'newamerican', 'title': 'American (New)'},
#    {'alias': 'tapasmallplates', 'title': 'Tapas/Small Plates'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 40.7275, 'longitude': -73.9838},
#   'transactions': [],
#   'price': '$$',
#   'location': {'address1': '424 E 9th St',
#    'address2': None,
#    'address3': '',
#    'city': 'New York',
#    'zip_code': '10009',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['424 E 9th St', 'New York, NY 10009']},
#   'phone': '',
#   'display_phone': '',
#   'distance': 175.89933919555247}]

# %% [markdown]
# There are a lot of key-value pairs for each business. Many of which we do not care about. Let's create a simple parser of this data that will return a tuple with the name, display_address, and one other data point of your choice.

# %%
business = data['businesses'][4]
business
# Out:
# {'id': 'FizBsTIAJwNrImIG1mPDcg',
#  'alias': 'barn-joo-new-york-3',
#  'name': 'Barn Joo',
#  'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/sQo30xQ5Blz5Z1ADmz9y5w/o.jpg',
#  'is_closed': False,
#  'url': 'https://www.yelp.com/biz/barn-joo-new-york-3?adjust_creative=F475wXQIdgD3Q7epch9QDA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=F475wXQIdgD3Q7epch9QDA',
#  'review_count': 1560,
#  'categories': [{'alias': 'korean', 'title': 'Korean'},
#   {'alias': 'bbq', 'title': 'Barbeque'},
#   {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#  'rating': 4.0,
#  'coordinates': {'latitude': 40.73684, 'longitude': -73.99069},
#  'transactions': ['pickup', 'delivery', 'restaurant_reservation'],
#  'price': '$$',
#  'location': {'address1': '35 Union Sq W',
#   'address2': '',
#   'address3': None,
#   'city': 'New York',
#   'zip_code': '10003',
#   'country': 'US',
#   'state': 'NY',
#   'display_address': ['35 Union Sq W', 'New York, NY 10003']},
#  'phone': '+16463989663',
#  'display_phone': '(646) 398-9663',
#  'distance': 1356.4203113978378}

# %%
biz_tuple = (business['name'], ' '.join(business['location']['display_address']) , business['rating'])
biz_tuple
# Out:
# ('Barn Joo', '35 Union Sq W New York, NY 10003', 4.0)

# %% [markdown]
# Now that we know how to do this for one business. Let create a function that recieves the list of businesses and returns a list of tuples with the important information.

# %%
def parse_data(businesses):
    biz_list = []
    
    for business in businesses:
        biz_tuple = (business['name'], ' '.join(business['location']['display_address']) , business['rating'])
        biz_list.append(biz_tuple)
    return biz_list
    
    
    # loop through our business and parse each individual business
    
    # in the loop, add each individual parsed parsed business to our data container
    
    # return the container with all of the parsed results

# %%
parse_data(data['businesses'])
# Out:
# [('Creative Little Garden', '530 E 6th St New York, NY 10009', 4.5),
#  ('6BC Botanical Garden', '624 6th St New York, NY 10009', 5.0),
#  ('Saifee Hardware & Garden', '114 1st Ave New York, NY 10009', 4.0),
#  ('9th Street Community Garden Park',
#   '700 E 9th St Ave C New York, NY 10009',
#   4.5),
#  ('Miracle Garden', '196 E 3rd St New York, NY 10009', 4.5),
#  ('Avant Garden', '130 E 7th St New York, NY 10009', 4.5),
#  ('Blue Meadow Flowers', '336 E 13th St New York, NY 10003', 5.0),
#  ('Crystals Garden', '247 E 10th St New York, NY 10009', 4.0),
#  ('Green Oasis Garden', '8th St Ave C & D New York, NY 10079', 5.0),
#  ('Dias Y Flores Garden', '520-522 E 13th St New York, NY 10009', 5.0),
#  ('11th Street Community Garden', '422 E 11th St New York, NY 10009', 3.5),
#  ('6th & B Garden', 'Corner Of 6th St And Ave B New York, NY 10009', 4.5),
#  ('El Sol Brillante Sr', '537 East 12th St New York, NY 10009', 5.0),
#  ('Carmen Pabon del Amanecer Garden', '115 Avenue C New York, NY 10009', 5.0),
#  ('El Jardin del Paraiso', 'E 4th & 5th St New York, NY 10019', 3.5),
#  ('Rue B', '188 Ave B New York, NY 10009', 4.0),
#  ("Sage's Garden", '281 E 4th St New York, NY 10009', 3.0),
#  ('Hope Garden', '191 E 2nd St New York, NY 10009', 4.0),
#  ('Orchard Alley', '350 E 4th St New York, NY 10009', 4.0),
#  ('Giano Restaurant', '126 E 7th St New York, NY 10009', 4.5)]

# %%
for element in data:
    print(element)
# Out:
# businesses
# total
# region
